# %%
import pandas as pd

# %%
df_alquiler = pd.read_csv('alquiler.csv', sep=';')

# %%
df_alquiler.head(50)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0           Habitación    San Borja        1         0       0    40
# 1                 Casa   Lurigancho        2         0       1   100
# 2      Local comercial          Ate        0         4       0   150
# 3         Departamento   Pachacámac        1         0       0    15
# 4         Departamento          Ate        1         0       0    48
# 5         Departamento     Barranco        3         1       0    70
# 6         Departamento        Comas        2         0       0    50
# 7   Casa en condominio          Ate        5         4       5   750
# 8   Casa en condominio  El Agustino        2         2       0    65
# 9      Local comercial   Pachacámac        0         3       0   695
# 10        Departamento   Pachacámac        1         0       0    36
# 11        Departamento      Mi Perú        2         1       0    70
# 12        Departamento    San Borja        3         1       1    90
# ...

# %%
df_alquiler.shape
# Out:
# (32960, 9)

# %%
list(df_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
seleccion = [
 'Terreno',
 'Chacra',
 'Terreno em condominio',
]

# %%
seleccion
# Out:
# ['Terreno', 'Chacra', 'Terreno em condominio']

# %%
filtro_seleccion= df_alquiler['Tipo'].isin(seleccion)

# %%
filtro_seleccion
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
df_lotes = df_alquiler[filtro_seleccion]

# %%
df_lotes.head(30)
# Out:
#                         Tipo                 Distrito  Cuartos  Vacantes  \
# 159                  Terreno                      Ate        0         0
# 551                  Terreno               Ventanilla        0         0
# 1365                 Terreno                      Ate        0         0
# 1505                 Terreno              Jesús María        0         0
# 1724                 Terreno                      Ate        0         0
# 2011                 Terreno              El Agustino        0         0
# 2157                  Chacra                    Ancón        3         0
# 2759                 Terreno                    Lince        0         0
# 2937                 Terreno                 San Luis        0         0
# 3354   Terreno em condominio            Punta Hermosa        0         0
# 3421                 Terreno              Jesús María        0         0
# 3931                 Terreno                 La Punta        0         0
# ...

# %%
list(df_lotes['Tipo'].drop_duplicates())
# Out:
# ['Terreno', 'Chacra', 'Terreno em condominio']

# %%
df_lotes.shape
# Out:
# (76, 9)

# %%
df_lotes.index = range(df_lotes.shape[0])

# %%
df_lotes
# Out:
#        Tipo     Distrito  Cuartos  Vacantes  Suites  Area     Valor  \
# 0   Terreno          Ate        0         0       0  1110  140000.0
# 1   Terreno   Ventanilla        0         0       0   721    4000.0
# 2   Terreno          Ate        0         0       0  1873   50000.0
# 3   Terreno  Jesús María        0         0       0  1290   18000.0
# 4   Terreno          Ate        0         0       0  1296   40000.0
# ..      ...          ...      ...       ...     ...   ...       ...
# 71  Terreno   Chorrillos        0         0       0   465   25000.0
# 72  Terreno          Ate        0         0       0  1110  140000.0
# 73  Terreno     San Luis        0         0       0  1200   30000.0
# 74  Terreno          Ate        1         0       0   529   35000.0
# 75  Terreno  Jesús María        0         0       0   800    8000.0
#
#     Mantenimiento  Impuesto
# 0             NaN       NaN
# 1             NaN     611.0
# 2             NaN    6392.0
# 3             NaN    1300.0
# ...

# %%
df_lotes.to_csv('alquiler_lotes.csv', sep=';', index = False)
