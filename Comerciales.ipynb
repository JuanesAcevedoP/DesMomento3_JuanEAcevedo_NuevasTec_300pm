# %%
import pandas as pd

# %%
df_alquiler = pd.read_csv('alquiler.csv', sep=';')

# %%
df_alquiler.head(50)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0           Habitación    San Borja        1         0       0    40
# 1                 Casa   Lurigancho        2         0       1   100
# 2      Local comercial          Ate        0         4       0   150
# 3         Departamento   Pachacámac        1         0       0    15
# 4         Departamento          Ate        1         0       0    48
# 5         Departamento     Barranco        3         1       0    70
# 6         Departamento        Comas        2         0       0    50
# 7   Casa en condominio          Ate        5         4       5   750
# 8   Casa en condominio  El Agustino        2         2       0    65
# 9      Local comercial   Pachacámac        0         3       0   695
# 10        Departamento   Pachacámac        1         0       0    36
# 11        Departamento      Mi Perú        2         1       0    70
# 12        Departamento    San Borja        3         1       1    90
# ...

# %%
df_alquiler.shape
# Out:
# (32960, 9)

# %%
list(df_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
seleccion = [
 'Local comercial',
 'Tienda/Salón',
 'Almacén',
 'Casa comercial',
 'Tienda en Centro Comercial',
 'Oficina',
 'Chalet',
 'Studio',
 'Hotel',
 'Local industrial']

# %%
seleccion
# Out:
# ['Local comercial',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Tienda en Centro Comercial',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
filtro_seleccion= df_alquiler['Tipo'].isin(seleccion)

# %%
filtro_seleccion
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959     True
# Name: Tipo, Length: 32960, dtype: bool

# %%
df_comercios = df_alquiler[filtro_seleccion]

# %%
df_comercios.head(30)
# Out:
#                 Tipo           Distrito  Cuartos  Vacantes  Suites   Area  \
# 2    Local comercial                Ate        0         4       0    150
# 9    Local comercial         Pachacámac        0         3       0    695
# 26   Local comercial        Punta Negra        0         1       0     25
# 29      Tienda/Salón              Lince        0         1       0     35
# 35   Local comercial                Ate        0         1       0     22
# 38   Local comercial         Pachacámac        0         5       0   1306
# 42   Local comercial        Jesús María        0         1       0     50
# 45   Local comercial         Pachacámac        0         0       0    460
# 46   Local comercial         Pachacámac        0         0       0   1170
# 52   Local comercial         Pachacámac        0         1       0     70
# 53   Local comercial         Lurigancho        0         1       0     50
# 58      Tienda/Salón          San Borja        0         0       0     34
# ...

# %%
list(df_comercios['Tipo'].drop_duplicates())
# Out:
# ['Local comercial',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Tienda en Centro Comercial',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
df_comercios.shape
# Out:
# (9394, 9)

# %%
df_comercios.index = range(df_comercios.shape[0])

# %%
df_comercios
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0     Local comercial          Ate        0         4       0   150   5200.0
# 1     Local comercial   Pachacámac        0         3       0   695  35000.0
# 2     Local comercial  Punta Negra        0         1       0    25   1100.0
# 3        Tienda/Salón        Lince        0         1       0    35   1300.0
# 4     Local comercial          Ate        0         1       0    22    700.0
# ...               ...          ...      ...       ...     ...   ...      ...
# 9389  Local comercial          Ate        0         1       0    36   1100.0
# 9390  Local comercial          Ate        0         1       0    55   2000.0
# 9391  Local comercial   Pachacámac        0         0       0   140   4000.0
# 9392  Local comercial   Pachacámac        0         0       0    32    600.0
# 9393  Local comercial   Pachacámac        0         0       0   250   6500.0
#
#       Mantenimiento  Impuesto
# ...

# %%
df_comercios.to_csv('alquiler_comercial.csv', sep=';', index = False)
