# %%
import numpy as np
import matplotlib as mpl

# %%
import pandas as pd

# %%
df= pd.DataFrame({'Curso':['Matemáticas', 'Biología', 'Estadística'], 'Créditos':[6, 4, 4], 'Horario':['M 6-9', 'J 6-9', 'V 6-9']})

# %%
print(df)
# Out:
#          Curso  Créditos Horario
# 0  Matemáticas         6   M 6-9
# 1     Biología         4   J 6-9
# 2  Estadística         4   V 6-9

# %%
print(df[['Curso','Horario']])
# Out:
#          Curso Horario
# 0  Matemáticas   M 6-9
# 1     Biología   J 6-9
# 2  Estadística   V 6-9

# %%
print(df[['Curso','Créditos']])
# Out:
#          Curso  Créditos
# 0  Matemáticas         6
# 1     Biología         4
# 2  Estadística         4

# %%
df2 = pd.read_csv('profesor.csv')

# %%
print(df2)
# Out:
#   Profesor  Aula  Nivel
# 0     Juan   503      1
# 1     José   404      2
# 2    Jaime   409      2

# %%
df3 = pd.concat([df,df2],axis=1)

# %%
print(df3)
# Out:
#          Curso  Créditos Horario Profesor  Aula  Nivel
# 0  Matemáticas         6   M 6-9     Juan   503      1
# 1     Biología         4   J 6-9     José   404      2
# 2  Estadística         4   V 6-9    Jaime   409      2

# %%
df3.to_csv('info_curso.csv')
